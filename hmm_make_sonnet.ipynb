# %%
import data_preprocess as data
from HMM import unsupervised_HMM
from HMM_sonnet_helper import sample_sonnet

# %%
obs, obs_map = data.get_shakes_lines()

# %%
hmm = unsupervised_HMM(obs, 50, 1000)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 1000/1000 [11:26:51<00:00, 41.21s/it]

# %%
sample_sonnet(hmm, obs_map)
# Out:
# Answer best excuse anger bootless and
# Hath sequent daily i be that i fair
# To say my deeds to seek but awakes my
# Or give of to return part and i her
# Found to knows to becoming gavst thou pine
# His were i mercy thee civil thee hang
# Shall as thy thought if thy shadow to praise
# Thereby that and did virtue that silver
# Wrinkles own shames be i found my outward
# Speechless saucy sick with thy dearest from
# Keeps from hopes by this fair and the greater
# Barren invention passed weeds who guard more
# They conceit in times trust that i seek her
# My me with them lives their his vassal of
# 'Answer best excuse anger bootless and\nHath sequent daily i be that i fair\nTo say my deeds to seek but awakes my\nOr give of to return part and i her\nFound to knows to becoming gavst thou pine\nHis were i mercy thee civil thee hang\nShall as thy thought if thy shadow to praise\nThereby that and did virtue that silver\nWrinkles own shames be i found my outward\nSpeechless saucy sick with thy dearest from\nKeeps from hopes by this fair and the greater\nBarren invention passed weeds who guard more\nThey conceit in times trust that i seek her\nMy me with them lives their his vassal of\n'

# %%
hmm2 = unsupervised_HMM(obs, 10, 10000)
sample_sonnet(hmm2, obs_map)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 10000/10000 [6:01:32<00:00,  2.17s/it]
# Leave seeting even gave their sight which best
# Such masonry beauteous base thine day to
# Pilgrimage tongue one of of the even
# Precious he i doth not waking wail the
# No due simple even nourished love to
# Fresh would such mind are straight war my tender
# You love heaven do wondrous proud marvel
# A end in sound he though thy beauteous sum
# That faults that flatter with you fill see your
# Threw a is moiety nearly love a me
# Love being forlorn mind the eyes of heart
# Lovst dost at made breast and until worthy
# Our eyes if i art i from knows thy
# Thy huswife with never sight witness time

# %% [markdown]
# Now let's visualize hmm2 since it has low number of states.
# We will follow the example in part_8.ipynb

# %%
import os
import numpy as np
from IPython.display import HTML
from HMM_helper_vis import (
    text_to_wordcloud,
    states_to_wordclouds,
    parse_observations,
    sample_sentence,
    visualize_sparsities,
    animate_emission,
    most_freq
)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\angel\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
most_freq(hmm2, obs_map)
# Out:
# The top 10 words for state 0 with stopwords are:
# and: 418
# but: 238
# o: 116
# so: 104
# for: 62
# or: 56
# who: 48
# then: 46
# when: 45
# how: 43
#
# The top 10 words for state 0 without stopwords are:
# thus: 28
# since: 19
# thief: 12
# yet: 11
# whilst: 11
# without: 11
# unseen: 11
# needs: 10
# friend: 9
# whether: 8
# The top 10 words for state 1 with stopwords are:
# and: 624
# that: 402
# in: 373
# with: 263
# which: 244
# to: 231
# as: 187
# art: 167
# are: 159
# but: 147
#
# The top 10 words for state 1 without stopwords are:
# wilt: 69
# whose: 63
# alone: 57
# mayst: 56
# like: 51
# yet: 50
# though: 47
# see: 47
# shall: 44
# shalt: 43
# The top 10 words for state 2 with stopwords are:
# of: 1126
# with: 520
# be: 491
# the: 377
# in: 361
# and: 340
# not: 292
# thy: 254
# thee: 212
# i: 198
#
# The top 10 words for state 2 without stopwords are:
# make: 146
# show: 106
# give: 79
# loves: 77
# upon: 70
# live: 65
# away: 63
# making: 62
# say: 59
# true: 58
# The top 10 words for state 3 with stopwords are:
# and: 725
# that: 479
# to: 386
# of: 342
# if: 211
# for: 188
# when: 177
# as: 146
# doth: 133
# a: 128
#
# The top 10 words for state 3 without stopwords are:
# shall: 96
# yet: 58
# let: 53
# since: 51
# precious: 34
# though: 33
# till: 30
# days: 27
# whilst: 24
# save: 21
# The top 10 words for state 4 with stopwords are:
# thou: 1100
# me: 387
# you: 370
# thee: 320
# that: 285
# i: 236
# they: 152
# all: 122
# her: 121
# him: 110
#
# The top 10 words for state 4 without stopwords are:
# love: 203
# time: 95
# nothing: 73
# live: 62
# lie: 51
# others: 51
# eyes: 49
# grace: 48
# yet: 47
# say: 42
# The top 10 words for state 5 with stopwords are:
# i: 1219
# that: 301
# it: 291
# not: 223
# which: 193
# he: 182
# you: 178
# thee: 177
# now: 116
# she: 107
#
# The top 10 words for state 5 without stopwords are:
# look: 106
# even: 98
# beauty: 79
# eyes: 49
# pen: 48
# one: 47
# heaven: 43
# though: 38
# dead: 36
# yet: 35
# The top 10 words for state 6 with stopwords are:
# or: 249
# will: 184
# own: 164
# more: 148
# is: 115
# to: 84
# was: 50
# me: 41
# very: 36
# dost: 34
#
# The top 10 words for state 6 without stopwords are:
# self: 329
# fair: 213
# sweet: 172
# name: 120
# truth: 100
# well: 95
# ill: 95
# love: 91
# eye: 84
# heart: 83
# The top 10 words for state 7 with stopwords are:
# more: 113
# me: 101
# that: 98
# not: 85
# other: 82
# such: 80
# most: 77
# them: 67
# up: 59
# should: 58
#
# The top 10 words for state 7 without stopwords are:
# love: 669
# eyes: 234
# self: 207
# time: 199
# heart: 194
# beauty: 158
# eye: 147
# world: 143
# true: 129
# best: 122
# The top 10 words for state 8 with stopwords are:
# the: 2281
# my: 2056
# thy: 1460
# your: 647
# a: 622
# his: 498
# this: 346
# so: 330
# no: 329
# their: 304
#
# The top 10 words for state 8 without stopwords are:
# mine: 323
# every: 118
# times: 108
# beautys: 106
# old: 98
# good: 84
# dear: 73
# sweet: 71
# see: 69
# summers: 68
# The top 10 words for state 9 with stopwords are:
# to: 1514
# in: 916
# is: 629
# of: 482
# for: 346
# from: 342
# by: 323
# do: 291
# all: 248
# doth: 246
#
# The top 10 words for state 9 without stopwords are:
# still: 125
# shall: 111
# may: 102
# upon: 88
# like: 87
# find: 82
# would: 76
# must: 72
# see: 64
# give: 62

# %%
anim = animate_emission(hmm2, obs_map, M=8)
HTML(anim.to_html5_video())
# Out:
# Animating...
# <video width="864" height="864" controls autoplay loop>
#   <source type="video/mp4" src="...
